# %%
import pandas as pd

# %%
pd.read_pickle(r'/mnt/e/Factor_Pool/alpha101/alpha001.pkl')
# Out:
#                000001    000002    000004  000005    000006    000007  \
# tradingdate
# 2010-01-04        NaN       NaN       NaN     NaN       NaN       NaN
# 2010-01-05        NaN       NaN       NaN     NaN       NaN       NaN
# 2010-01-06        NaN       NaN       NaN     NaN       NaN       NaN
# 2010-01-07        NaN       NaN       NaN     NaN       NaN       NaN
# 2010-01-08        NaN       NaN  0.201299     NaN       NaN       NaN
# ...               ...       ...       ...     ...       ...       ...
# 2024-07-18   0.881028  0.881028  0.502897     NaN  0.138972  0.881028
# 2024-07-19   0.545981  0.545981  0.812430     NaN  0.400187  0.545981
# 2024-07-22   0.406712  0.406712  0.818751     NaN  0.273322  0.818751
# 2024-07-23   0.220322  0.220322  0.708544     NaN  0.959899  0.708544
# 2024-07-24   0.095906  0.095906  0.960273     NaN  0.887082  0.636474
#
#                000008    000009    000010    000011  ...    873593    873665  \
# tradingdate                                          ...
# 2010-01-04        NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2010-01-05        NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2010-01-06        NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2010-01-07        NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2010-01-08   0.201299       NaN       NaN       NaN  ...       NaN       NaN
# ...               ...       ...       ...       ...  ...       ...       ...
# 2024-07-18   0.881028  0.694393  0.881028  0.138972  ...  0.694393  0.694393
# 2024-07-19   0.812430  0.400187  0.545981  0.400187  ...  0.400187  0.400187
# 2024-07-22   0.556927  0.273322  0.406712  0.273322  ...  0.273322  0.273322
# 2024-07-23   0.959899  0.070387  0.220322  0.070387  ...  0.070387  0.070387
# 2024-07-24   0.887082  0.636474  0.095906  0.305478  ...  0.887082  0.960273
#
#                873679    873690    873693    873703    873706    873726  \
# tradingdate
# 2010-01-04        NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05        NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-06        NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-07        NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-08        NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# 2024-07-18   0.694393  0.694393  0.694393  0.694393  0.694393  0.694393
# 2024-07-19   0.400187  0.400187  0.400187  0.400187  0.400187  0.400187
# 2024-07-22   0.273322  0.273322  0.273322  0.273322  0.273322  0.273322
# 2024-07-23   0.070387  0.070387  0.070387  0.070387  0.070387  0.070387
# 2024-07-24   0.095906  0.305478  0.960273  0.636474  0.095906  0.636474
#
#                873806    873833
# tradingdate
# 2010-01-04        NaN       NaN
# 2010-01-05        NaN       NaN
# 2010-01-06        NaN       NaN
# 2010-01-07        NaN       NaN
# 2010-01-08        NaN       NaN
# ...               ...       ...
# 2024-07-18   0.694393  0.694393
# 2024-07-19   0.400187  0.400187
# 2024-07-22   0.273322  0.273322
# 2024-07-23   0.070387  0.070387
# 2024-07-24   0.636474  0.305478
#
# [3536 rows x 5552 columns]

# %%
from KunQuant.Op import *
from KunQuant.ops import *

class AllData:
    def __init__(self, open: OpBase, close: OpBase = None, high: OpBase = None,
     low: OpBase = None, volume: OpBase = None, amount: OpBase = None, vwap: OpBase = None) -> None:
        self.open = open
        self.close = close
        self.high = high
        self.low = low
        self.volume = volume
        self.amount = amount
        if vwap is None:
            self.vwap = Div(self.amount, AddConst(self.volume, 0.0000001))
        else:
            self.vwap = vwap
        self.returns = returns(close)

def stddev(v: OpBase, window: int) -> OpBase:
    return WindowedStddev(v, window)

def returns(v: OpBase) -> OpBase:
    prev1 = BackRef(v, 1)
    return SubConst(Div(v, prev1), 1.0)

def ts_argmax(v: OpBase, window: int) -> OpBase:
    return TsArgMax(v, window)

def ts_argmin(v: OpBase, window: int) -> OpBase:
    return TsArgMin(v, window)

def ts_rank(v: OpBase, window: int) -> OpBase:
    return TsRank(v, window)

def ts_sum(v: OpBase, window: int) -> OpBase:
    return WindowedSum(v, window)

def ts_min(v: OpBase, window: int) -> OpBase:
    return WindowedMin(v, window)

def ts_max(v: OpBase, window: int) -> OpBase:
    return WindowedMax(v, window)

def correlation(v1: OpBase, v2: OpBase, window: int) -> OpBase:
    return WindowedCorrelation(v1, window, v2)

def delta(v1: OpBase, window: int = 1) -> OpBase:
    return Sub(v1, BackRef(v1, window))

def rank(v: OpBase)-> OpBase:
    return Rank(v)

def sign(v: OpBase)-> OpBase:
    return Sign(v)

def covariance(v: OpBase, v2: OpBase, window: int) -> OpBase:
    return WindowedCovariance(v, window, v2)

def sma(v: OpBase, window: int) -> OpBase:
    return WindowedAvg(v, window)

def bool_to_10(v: OpBase) -> OpBase:
    return Select(v, ConstantOp(1), ConstantOp(0))

scale = Scale

delay = BackRef
decay_linear = DecayLinear

def Risk001(self: AllData):
    inner = self.close
    return Sqrt(WindowedAvg(inner,60))

# %%
# Out:
# /tmp/ipykernel_48888/1919307648.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['PctChange'] = (data['adjclose']-data['adjpreclose'])/(data['adjpreclose']+1e-8)
# /tmp/ipykernel_48888/1919307648.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['OpenPctChange'] = (data['adjopen']-data['adjpreclose'])/(data['adjpreclose']+1e-8)
# /tmp/ipykernel_48888/1919307648.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['HighPctChange'] = (data['adjhigh']-data['adjpreclose'])/(data['adjpreclose']+1e-8)
# /tmp/ipykernel_48888/1919307648.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['LowPctChange'] = (data['adjlow']-data['adjpreclose'])/(data['adjpreclose']+1e-8)
# /tmp/ipykernel_48888/1919307648.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['VwapPctChange'] = (data['adjvwap']-data['adjpreclose'])/(data['adjpreclose']+1e-8)
# /tmp/ipykernel_48888/1919307648.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['CloseOpenPct'] = (data['adjclose']-data['adjopen'])/(data['adjopen']+1e-8)
# /tmp/ipykernel_48888/1919307648.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['HighLowPct'] = (data['adjhigh']-data['adjlow'])/(data['adjlow']+1e-8)
# /tmp/ipykernel_48888/1919307648.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['TR'] = np.maximum(data['adjhigh']-data['adjlow'],np.abs(data['adjhigh']-data['adjpreclose']),np.abs(data['adjlow']-data['adjpreclose']))/data['adjpreclose']
# /tmp/ipykernel_48888/1919307648.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['OpenExRet'] = data['OpenPctChange'] - data['PctChange'].groupby('tradingdate').transform('median')
# /tmp/ipykernel_48888/1919307648.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['HighExRet'] = data['HighPctChange'] - data['PctChange'].groupby('tradingdate').transform('median')
# /tmp/ipykernel_48888/1919307648.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['LowExRet'] = data['LowPctChange'] - data['PctChange'].groupby('tradingdate').transform('median')
# /tmp/ipykernel_48888/1919307648.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['CloseExRet'] = data['PctChange'] - data['PctChange'].groupby('tradingdate').transform('median')
