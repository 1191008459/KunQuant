# %%
import pandas as pd

# %%
pd.read_pickle(r'/mnt/e/Feature_Pool/daily/adjvolume.pkl')
# Out:
# <xarray.DataArray (tradingdate: 3539, stockcode: 5554)>
# array([[ 6737.7563,  8752.676 ,     0.    , ...,        nan,        nan,
#                nan],
#        [15498.998 , 16683.684 ,     0.    , ...,        nan,        nan,
#                nan],
#        [11478.54  , 12261.314 ,     0.    , ...,        nan,        nan,
#                nan],
#        ...,
#        [ 6891.283 ,  3022.8816, 47192.168 , ..., 58228.832 ,  3454.831 ,
#         23627.695 ],
#        [ 7452.095 ,  3495.9863, 38970.14  , ..., 48527.53  ,  4427.726 ,
#         17680.248 ],
#        [ 6301.6655,  3570.9229, 47153.48  , ..., 74422.11  ,  2114.252 ,
#         17508.533 ]], dtype=float32)
# Coordinates:
#   * tradingdate  (tradingdate) datetime64[ns] 2010-01-04 ... 2024-07-29
#   * stockcode    (stockcode) object '000001' '000002' ... '873833' '920002'

# %%
data = pd.read_hdf(r'/mnt/d/sl_code/data_update/daily_base_stock.h5')

# %%
data
# Out:
#                        tradestatus  updown       size        mktcap  \
# tradingdate stockcode
# 2005-01-04  000001               1     0.0  14.053484  1.268676e+06
#             000002               1     0.0  13.996333  1.198202e+06
#             000004               1     0.0  10.937817  5.626438e+04
#             000005               1     0.0  11.924670  1.509449e+05
#             000006               1     0.0  11.575980  1.065085e+05
# ...                            ...     ...        ...           ...
# 2024-07-30  873706               1     0.0  11.352759  7.993054e+04
#             873726               1     0.0  11.897073  1.468362e+05
#             873806               1     0.0  12.521875  2.742718e+05
#             873833               1     0.0  11.352759  6.588800e+04
#             920002               1     0.0  11.942774  1.537025e+05
#
#                        float_mktcap  adjpreclose  adjclose   adjopen  \
# tradingdate stockcode
# ...
