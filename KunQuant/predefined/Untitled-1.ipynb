# %%
import pandas as pd

# %%
pd.read_pickle(r'/mnt/e/Feature_Pool/daily/adjvolume.pkl')
# Out:
# <xarray.DataArray (tradingdate: 3537, stockcode: 5553)>
# array([[ 6737.7563,  8752.676 ,     0.    , ...,        nan,        nan,
#                nan],
#        [15498.998 , 16683.684 ,     0.    , ...,        nan,        nan,
#                nan],
#        [11478.54  , 12261.314 ,     0.    , ...,        nan,        nan,
#                nan],
#        ...,
#        [ 8158.0093,  5361.6523, 74614.586 , ..., 71727.16  ,  3808.7532,
#          6702.77  ],
#        [ 5793.854 ,  6348.2095, 57009.902 , ..., 77318.086 ,  4116.8022,
#          6862.79  ],
#        [ 6891.283 ,  3022.8816, 47192.168 , ..., 58228.832 ,  3454.831 ,
#         23627.695 ]], dtype=float32)
# Coordinates:
#   * tradingdate  (tradingdate) datetime64[ns] 2010-01-04 ... 2024-07-25
#   * stockcode    (stockcode) object '000001' '000002' ... '873833' '920002'
